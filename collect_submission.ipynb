# %%
import torch
torch.cuda.is_available()#check if GPU is available
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# NOTE: make sure to change the path bellow to path to YOUR assigment folder
# %cd /content/drive/MyDrive/cse182_hw3_colab/
# !pwd
# Out:
# /content/drive/MyDrive/cse182_hw3_colab
# /content/drive/MyDrive/cse182_hw3_colab

# %%
from google.colab import files
files.download('hw3_submission.zip')
